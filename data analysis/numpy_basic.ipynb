# %%
import numpy as np

# %%
np.set_printoptions(precision=2)

# %%
b= np.array([[1,2,3],[4,5,6]])
print(b)
print(b.shape)
print(b.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
# 2

# %%
a=np.array([1,2,3])
print(a)
print(a.shape)
print(b.ndim)
# Out:
# [1 2 3]
# (3,)
# 2

# %%
c = np.array([
    [[1,2,3],
    [2,3,4],
    [2,2,2]],
    [[1,2,3],
    [2,3,4],
    [2,2,2]],
    ])

print(c)
print(c.shape)
print(c.dtype)
# Out:
# [[[1 2 3]
#   [2 3 4]
#   [2 2 2]]
#
#  [[1 2 3]
#   [2 3 4]
#   [2 2 2]]]
# (2, 3, 3)
# int32

# %%
import numpy as np

c = np.array([
    [
        [[1, 2, 3],
         [2, 3, 4],
         [2, 2, 2]],

        [[1, 2, 3],
         [2, 3, 4],
         [2, 2, 2]]
    ],
    [
        [[4, 5, 6],
         [5, 6, 7],
         [6, 6, 6]],

        [[4, 5, 6],
         [5, 6, 7],
         [6, 6, 6]]
    ],
    [
        [[7, 8, 9],
         [8, 9, 10],
         [9, 9, 9]],

        [[7, 8, 9],
         [8, 9, 10],
         [9, 9, 9]]
    ]
])

print("4D Array:")
print(c)
# Out:
# 4D Array:
# [[[[ 1  2  3]
#    [ 2  3  4]
#    [ 2  2  2]]
#
#   [[ 1  2  3]
#    [ 2  3  4]
#    [ 2  2  2]]]
#
#
#  [[[ 4  5  6]
#    [ 5  6  7]
#    [ 6  6  6]]
#
#   [[ 4  5  6]
#    [ 5  6  7]
#    [ 6  6  6]]]
#
#
#  [[[ 7  8  9]
#    [ 8  9 10]
#    [ 9  9  9]]
#
#   [[ 7  8  9]
#    [ 8  9 10]
#    [ 9  9  9]]]]

# %% [markdown]
# - generate matrix
# * linear
# * random

# %%
a= np.arange(1,10,0.02)
print(a)
a.size
# Out:
# [1.   1.02 1.04 1.06 1.08 1.1  1.12 1.14 1.16 1.18 1.2  1.22 1.24 1.26
#  1.28 1.3  1.32 1.34 1.36 1.38 1.4  1.42 1.44 1.46 1.48 1.5  1.52 1.54
#  1.56 1.58 1.6  1.62 1.64 1.66 1.68 1.7  1.72 1.74 1.76 1.78 1.8  1.82
#  1.84 1.86 1.88 1.9  1.92 1.94 1.96 1.98 2.   2.02 2.04 2.06 2.08 2.1
#  2.12 2.14 2.16 2.18 2.2  2.22 2.24 2.26 2.28 2.3  2.32 2.34 2.36 2.38
#  2.4  2.42 2.44 2.46 2.48 2.5  2.52 2.54 2.56 2.58 2.6  2.62 2.64 2.66
#  2.68 2.7  2.72 2.74 2.76 2.78 2.8  2.82 2.84 2.86 2.88 2.9  2.92 2.94
#  2.96 2.98 3.   3.02 3.04 3.06 3.08 3.1  3.12 3.14 3.16 3.18 3.2  3.22
#  3.24 3.26 3.28 3.3  3.32 3.34 3.36 3.38 3.4  3.42 3.44 3.46 3.48 3.5
#  3.52 3.54 3.56 3.58 3.6  3.62 3.64 3.66 3.68 3.7  3.72 3.74 3.76 3.78
#  3.8  3.82 3.84 3.86 3.88 3.9  3.92 3.94 3.96 3.98 4.   4.02 4.04 4.06
#  4.08 4.1  4.12 4.14 4.16 4.18 4.2  4.22 4.24 4.26 4.28 4.3  4.32 4.34
#  4.36 4.38 4.4  4.42 4.44 4.46 4.48 4.5  4.52 4.54 4.56 4.58 4.6  4.62
#  4.64 4.66 4.68 4.7  4.72 4.74 4.76 4.78 4.8  4.82 4.84 4.86 4.88 4.9
#  4.92 4.94 4.96 4.98 5.   5.02 5.04 5.06 5.08 5.1  5.12 5.14 5.16 5.18
#  5.2  5.22 5.24 5.26 5.28 5.3  5.32 5.34 5.36 5.38 5.4  5.42 5.44 5.46
#  5.48 5.5  5.52 5.54 5.56 5.58 5.6  5.62 5.64 5.66 5.68 5.7  5.72 5.74
#  5.76 5.78 5.8  5.82 5.84 5.86 5.88 5.9  5.92 5.94 5.96 5.98 6.   6.02
#  6.04 6.06 6.08 6.1  6.12 6.14 6.16 6.18 6.2  6.22 6.24 6.26 6.28 6.3
#  6.32 6.34 6.36 6.38 6.4  6.42 6.44 6.46 6.48 6.5  6.52 6.54 6.56 6.58
#  6.6  6.62 6.64 6.66 6.68 6.7  6.72 6.74 6.76 6.78 6.8  6.82 6.84 6.86
#  6.88 6.9  6.92 6.94 6.96 6.98 7.   7.02 7.04 7.06 7.08 7.1  7.12 7.14
#  7.16 7.18 7.2  7.22 7.24 7.26 7.28 7.3  7.32 7.34 7.36 7.38 7.4  7.42
#  7.44 7.46 7.48 7.5  7.52 7.54 7.56 7.58 7.6  7.62 7.64 7.66 7.68 7.7
#  7.72 7.74 7.76 7.78 7.8  7.82 7.84 7.86 7.88 7.9  7.92 7.94 7.96 7.98
#  8.   8.02 8.04 8.06 8.08 8.1  8.12 8.14 8.16 8.18 8.2  8.22 8.24 8.26
#  8.28 8.3  8.32 8.34 8.36 8.38 8.4  8.42 8.44 8.46 8.48 8.5  8.52 8.54
#  8.56 8.58 8.6  8.62 8.64 8.66 8.68 8.7  8.72 8.74 8.76 8.78 8.8  8.82
#  8.84 8.86 8.88 8.9  8.92 8.94 8.96 8.98 9.   9.02 9.04 9.06 9.08 9.1
#  9.12 9.14 9.16 9.18 9.2  9.22 9.24 9.26 9.28 9.3  9.32 9.34 9.36 9.38
#  9.4  9.42 9.44 9.46 9.48 9.5  9.52 9.54 9.56 9.58 9.6  9.62 9.64 9.66
#  9.68 9.7  9.72 9.74 9.76 9.78 9.8  9.82 9.84 9.86 9.88 9.9  9.92 9.94
#  9.96 9.98]
# 450

# %%
a= np.arange(-np.pi , np.pi,.25)
print(a)
# Out:
# [-3.14 -2.89 -2.64 -2.39 -2.14 -1.89 -1.64 -1.39 -1.14 -0.89 -0.64 -0.39
#  -0.14  0.11  0.36  0.61  0.86  1.11  1.36  1.61  1.86  2.11  2.36  2.61
#   2.86  3.11]

# %%
b= np.linspace(1,10,100)
print(b)
# Out:
# [ 1.    1.09  1.18  1.27  1.36  1.45  1.55  1.64  1.73  1.82  1.91  2.
#   2.09  2.18  2.27  2.36  2.45  2.55  2.64  2.73  2.82  2.91  3.    3.09
#   3.18  3.27  3.36  3.45  3.55  3.64  3.73  3.82  3.91  4.    4.09  4.18
#   4.27  4.36  4.45  4.55  4.64  4.73  4.82  4.91  5.    5.09  5.18  5.27
#   5.36  5.45  5.55  5.64  5.73  5.82  5.91  6.    6.09  6.18  6.27  6.36
#   6.45  6.55  6.64  6.73  6.82  6.91  7.    7.09  7.18  7.27  7.36  7.45
#   7.55  7.64  7.73  7.82  7.91  8.    8.09  8.18  8.27  8.36  8.45  8.55
#   8.64  8.73  8.82  8.91  9.    9.09  9.18  9.27  9.36  9.45  9.55  9.64
#   9.73  9.82  9.91 10.  ]

# %%
b.reshape(25,4)
# Out:
# array([[ 1.  ,  1.09,  1.18,  1.27],
#        [ 1.36,  1.45,  1.55,  1.64],
#        [ 1.73,  1.82,  1.91,  2.  ],
#        [ 2.09,  2.18,  2.27,  2.36],
#        [ 2.45,  2.55,  2.64,  2.73],
#        [ 2.82,  2.91,  3.  ,  3.09],
#        [ 3.18,  3.27,  3.36,  3.45],
#        [ 3.55,  3.64,  3.73,  3.82],
#        [ 3.91,  4.  ,  4.09,  4.18],
#        [ 4.27,  4.36,  4.45,  4.55],
#        [ 4.64,  4.73,  4.82,  4.91],
#        [ 5.  ,  5.09,  5.18,  5.27],
#        [ 5.36,  5.45,  5.55,  5.64],
#        [ 5.73,  5.82,  5.91,  6.  ],
#        [ 6.09,  6.18,  6.27,  6.36],
#        [ 6.45,  6.55,  6.64,  6.73],
#        [ 6.82,  6.91,  7.  ,  7.09],
#        [ 7.18,  7.27,  7.36,  7.45],
#        [ 7.55,  7.64,  7.73,  7.82],
#        [ 7.91,  8.  ,  8.09,  8.18],
#        [ 8.27,  8.36,  8.45,  8.55],
#        [ 8.64,  8.73,  8.82,  8.91],
#        [ 9.  ,  9.09,  9.18,  9.27],
#        [ 9.36,  9.45,  9.55,  9.64],
#        [ 9.73,  9.82,  9.91, 10.  ]])

# %%
b.reshape(5,5,4)
# Out:
# array([[[ 1.  ,  1.09,  1.18,  1.27],
#         [ 1.36,  1.45,  1.55,  1.64],
#         [ 1.73,  1.82,  1.91,  2.  ],
#         [ 2.09,  2.18,  2.27,  2.36],
#         [ 2.45,  2.55,  2.64,  2.73]],
#
#        [[ 2.82,  2.91,  3.  ,  3.09],
#         [ 3.18,  3.27,  3.36,  3.45],
#         [ 3.55,  3.64,  3.73,  3.82],
#         [ 3.91,  4.  ,  4.09,  4.18],
#         [ 4.27,  4.36,  4.45,  4.55]],
#
#        [[ 4.64,  4.73,  4.82,  4.91],
#         [ 5.  ,  5.09,  5.18,  5.27],
#         [ 5.36,  5.45,  5.55,  5.64],
#         [ 5.73,  5.82,  5.91,  6.  ],
#         [ 6.09,  6.18,  6.27,  6.36]],
#
#        [[ 6.45,  6.55,  6.64,  6.73],
#         [ 6.82,  6.91,  7.  ,  7.09],
#         [ 7.18,  7.27,  7.36,  7.45],
#         [ 7.55,  7.64,  7.73,  7.82],
#         [ 7.91,  8.  ,  8.09,  8.18]],
#
#        [[ 8.27,  8.36,  8.45,  8.55],
#         [ 8.64,  8.73,  8.82,  8.91],
#         [ 9.  ,  9.09,  9.18,  9.27],
#         [ 9.36,  9.45,  9.55,  9.64],
#         [ 9.73,  9.82,  9.91, 10.  ]]])

# %%
print(np.random.rand(3,3))
# Out:
# [[0.18 0.93 0.25]
#  [0.48 0.8  0.28]
#  [0.43 0.18 0.88]]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 y = np.random.randint(1,11,(3,3))
# ----> 2 print(x)
#       3 print(y)
#
# NameError: name 'x' is not defined
