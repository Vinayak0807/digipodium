# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

import seaborn as sns

# %%
df = pd.read_csv('country_wise_latest.csv')

# %%
df.head(5)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.shape
# Out:
# (187, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
# ...

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
df.rename(columns={'Country/Region':'Country'}, inplace=True)

# %%
df.sort_values(by='Deaths', ascending=False,inplace=True)

# %%
ss=df[['Country','Deaths']].head(5)

# %%
ss
ss['Confirmed'] = pd.to_numeric(ss['Confirmed'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Vinayak\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Vinayak\miniconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Vinayak\miniconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Confirmed'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# top 5 country in deaths occured in covid

# %%
sns.barplot(x ='Country',y='Deaths' ,data =ss )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head(5)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
# 2      Algeria      27973    1163      18837    7973        616           8
# 3      Andorra        907      52        803      52         10           0
# 4       Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.sort_values(by='Active', ascending=False,inplace=True)

# %%
sd=df[['Country','Active']].head(10)

# %%
df
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 177  United Kingdom     301708   45844       1437   254427        688
# 138          Russia     816680   13334     602249   201097       5607
# ..              ...        ...     ...        ...      ...        ...
# 75         Holy See         12       0         12        0          0
# 143      San Marino        699      42        657        0          0
# 24           Brunei        141       3        138        0          0
# 49         Dominica         18       0         18        0          0
# 69          Grenada         23       0         23        0          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x ='Country',y='Active' ,data =sd)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fd = df.head(10)

# %%
df.groupby('Deaths')
df
# Out:
#             Country  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# ..              ...        ...     ...        ...      ...        ...
# 94             Laos         20       0         19        1          0
# 68        Greenland         14       0         13        1          1
# 30         Cambodia        226       0        147       79          1
# 69          Grenada         23       0         23        0          0
# 114        Mongolia        289       0        222       67          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x ='Country',y='New cases' ,data =fd)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values(by='New recovered', ascending=False,inplace=True)

# %%
cd=df.head(5)

# %% [markdown]
# TOP 5 COUNTRY RECOVERED PATIENT BY COVID 19

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x ='Country',y='New recovered' ,data =fd)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.xlabel('Date')
plt.ylabel('Data Value')
plt.title('Data Comparison for Country A and Country B')
plt.legend()

plt.grid(True)
plt.show(
