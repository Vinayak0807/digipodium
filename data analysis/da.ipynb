# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
pd.read_excel('100000 records of sheet.xlsx',sheet_name=0,skiprows=None,skipfooter=0)
# Out:
#       Emp ID MY PATTERN Name Prefix First Name Middle Initial    Last Name  \
# 0     857665        NaN         Dr.     Antone              Q        Appel
# 1     223381        NaN         Mr.     Arthur              E       Arvizu
# 2     670592        NaN         Mr.      Brian              J  Baskerville
# 3     467879        NaN        Hon.       Elma              N       Baucom
# 4     184988        NaN        Drs.     Noella              K       Binder
# ...      ...        ...         ...        ...            ...          ...
# 9995  137698        NaN        Mrs.   Waltraud              L        Vigil
# 9996  356126        NaN         Dr.       Tony              T      Waltman
# 9997  850342        NaN         Mr.      Kirby              F      Wilhelm
# 9998  994968        NaN         Ms.      Darla              G      Windsor
# 9999  738024        NaN        Drs.      Staci              G         Word
#
#      Gender                        E Mail        Father's Name  \
# 0         M        antone.appel@gmail.com          Micah Appel
# 1         M    arthur.arvizu@ntlworld.com        Travis Arvizu
# 2         M     brian.baskerville@aol.com  Clayton Baskerville
# 3         F    elma.baucom@rediffmail.com     Margarito Baucom
# 4         F         noella.binder@ibm.com        Santos Binder
# ...     ...                           ...                  ...
# 9995      F        waltraud.vigil@cox.net          Elton Vigil
# 9996      M        tony.waltman@gmail.com      Linwood Waltman
# 9997      M  kirby.wilhelm@exxonmobil.com        Graig Wilhelm
# 9998      F        darla.windsor@yahoo.ca        Brent Windsor
# 9999      F            staci.word@cox.net             Kim Word
#
#         Mother's Name Mother's Maiden Name Date of Birth Time of Birth  \
# 0        Odette Appel              Valadez    1967-12-22      19:35:30
# 1       Reanna Arvizu               Farber    1972-08-24      16:33:02
# 2     Kum Baskerville              Peoples    1984-01-14      13:35:31
# 3        Elmer Baucom              Rothman    1958-06-07      19:56:21
# 4      Sharice Binder                Giles    1965-11-29      08:35:24
# ...               ...                  ...           ...           ...
# 9995      Sandy Vigil              Laroche    1993-06-18      08:36:10
# 9996   Diedre Waltman                Range    1970-07-26      20:46:08
# 9997  Pandora Wilhelm              Bingham    1968-05-11      00:45:17
# 9998   Denita Windsor                Hoard    1990-08-17      19:17:06
# 9999       Karri Word              Redwine    1958-11-25      18:16:52
#
#       Age in Yrs.  Weight in Kgs. Date of Joining Quarter of Joining  \
# 0           49.63              78      2004-02-22                 Q1
# 1           44.96              79      2009-02-01                 Q1
# 2           33.56              72      2016-02-14                 Q1
# 3           59.18              51      2004-02-22                 Q1
# 4           51.70              58      1988-02-28                 Q1
# ...           ...             ...             ...                ...
# 9995        24.13              42      2014-10-04                 Q4
# 9996        47.04              56      2016-10-15                 Q4
# 9997        49.25              53      1998-10-31                 Q4
# 9998        26.96              45      2016-10-22                 Q4
# 9999        58.71              51      1998-10-10                 Q4
#
#      Half of Joining  Year of Joining  Month of Joining Month Name of Joining  \
# 0                 H1           2004.0                 2              February
# 1                 H1           2009.0                 2              February
# 2                 H1           2016.0                 2              February
# 3                 H1           2004.0                 2              February
# 4                 H1           1988.0                 2              February
# ...              ...              ...               ...                   ...
# 9995              H2           2014.0                10               October
# 9996              H2           2016.0                10               October
# 9997              H2           1998.0                10               October
# 9998              H2           2016.0                10               October
# 9999              H2           1998.0                10               October
#
#      Short Month  Day of Joining DOW of Joining Short DOW  \
# 0            Feb              22         Sunday       Sun
# 1            Feb               1         Sunday       Sun
# 2            Feb              14         Sunday       Sun
# 3            Feb              22         Sunday       Sun
# 4            Feb              28         Sunday       Sun
# ...          ...             ...            ...       ...
# 9995         Oct               4       Saturday       Sat
# 9996         Oct              15       Saturday       Sat
# 9997         Oct              31       Saturday       Sat
# 9998         Oct              22       Saturday       Sat
# 9999         Oct              10       Saturday       Sat
#
#       Age in Company (Years)  Salary  Tax Eligibility  Tax Percentage  \
# 0                      13.44  149793             True             NaN
# 1                       8.49  133073             True             NaN
# 2                       1.45   50982            False             NaN
# 3                      13.44  171682             True             NaN
# 4                      29.43  108261             True             NaN
# ...                      ...     ...              ...             ...
# 9995                    2.82   77395            False             NaN
# 9996                    0.78   78910            False             NaN
# 9997                   18.75   65134            False             NaN
# 9998                    0.76   99409            False             NaN
# 9999                   18.81   75376            False             NaN
#
#       Last % Hike          SSN    Phone No.  Place Name             County  \
# 0            0.25  403-73-7467  270-644-7854  Pendleton              Henry
# 1            0.01  626-85-9091  225-578-5774    Leander            Leander
# 2            0.24  654-38-3428  215-589-4268  Centralia           Columbia
# 3            0.16  158-23-7131  228-894-7251   Tribbett           Tribbett
# 4            0.02  083-02-2333  216-487-7347   Columbus           Franklin
# ...           ...          ...           ...        ...                ...
# 9995         0.17  360-08-5960  907-925-1315   Skwentna  Matanuska-Susitna
# 9996         0.17  723-18-7221  228-806-8755   Saltillo                Lee
# 9997         0.17  023-92-0684  405-305-8169      Tulsa              Tulsa
# 9998         0.02  034-92-9671  239-849-3909      Miami         Miami-Dade
# 9999         0.21  270-17-2090  218-819-2054     Morris            Stevens
#
#            City State      Zip     Region      User Name        Password  \
# 0     Pendleton    KY  40055.0      South        aqappel     v]v*;4FwqL>
# 1       Leander    LA  71445.0      South       aearvizu       7dUsJd!L#
# 2     Centralia    PA  17927.0  Northeast  bjbaskerville      6WvugA]g5N
# 3      Tribbett    MS  38779.0      South       enbaucom       8XkHcpm--
# 4      Columbus    OH  43271.0    Midwest       nkbinder    nm-a7n_}^w4/
# ...         ...   ...      ...        ...            ...             ...
# 9995   Skwentna    AK  99667.0       West        wlvigil       HG_kqGC~t
# 9996   Saltillo    MS  38866.0      South      ttwaltman  miM$Tfb_YPBYpo
# 9997      Tulsa    OK  74137.0      South      kfwilhelm    q}_@KuzXYO<6
# 9998      Miami    FL  33296.0      South      dgwindsor   X;.k25@.Gg;ik
# 9999     Morris    MN  56267.0    Midwest         sgword       l?T@mC.;B
#
#       Unnamed: 40  Unnamed: 41  Unnamed: 42 count numerical value  \
# 0             NaN          NaN          NaN     count every value
# 1             NaN          NaN          NaN          count blanks
# 2             NaN          NaN          NaN               countif
# 3             NaN          NaN          NaN                   NaN
# 4             NaN          NaN          NaN                   NaN
# ...           ...          ...          ...                   ...
# 9995          NaN          NaN          NaN                   NaN
# 9996          NaN          NaN          NaN                   NaN
# 9997          NaN          NaN          NaN                   NaN
# 9998          NaN          NaN          NaN                   NaN
# 9999          NaN          NaN          NaN                   NaN
#
#       Unnamed: 44    9993
# 0             NaN  9993.0
# 1             NaN     7.0
# 2             NaN   656.0
# 3             NaN     NaN
# 4             NaN     NaN
# ...           ...     ...
# 9995          NaN     NaN
# 9996          NaN     NaN
# 9997          NaN     NaN
# 9998          NaN     NaN
# 9999          NaN     NaN
#
# [10000 rows x 46 columns]

# %%
pd.set_option('display.max_columns',None)

# %%
fd = pd.read_excel('100000 records of sheet.xlsx',sheet_name=0,skiprows=None,skipfooter=0)

# %%
fd.head()
# Out:
#    Emp ID MY PATTERN Name Prefix First Name Middle Initial    Last Name  \
# 0  857665        NaN         Dr.     Antone              Q        Appel
# 1  223381        NaN         Mr.     Arthur              E       Arvizu
# 2  670592        NaN         Mr.      Brian              J  Baskerville
# 3  467879        NaN        Hon.       Elma              N       Baucom
# 4  184988        NaN        Drs.     Noella              K       Binder
#
#   Gender                      E Mail        Father's Name    Mother's Name  \
# 0      M      antone.appel@gmail.com          Micah Appel     Odette Appel
# 1      M  arthur.arvizu@ntlworld.com        Travis Arvizu    Reanna Arvizu
# 2      M   brian.baskerville@aol.com  Clayton Baskerville  Kum Baskerville
# 3      F  elma.baucom@rediffmail.com     Margarito Baucom     Elmer Baucom
# 4      F       noella.binder@ibm.com        Santos Binder   Sharice Binder
#
#   Mother's Maiden Name Date of Birth Time of Birth  Age in Yrs.  \
# 0              Valadez    1967-12-22      19:35:30        49.63
# 1               Farber    1972-08-24      16:33:02        44.96
# 2              Peoples    1984-01-14      13:35:31        33.56
# 3              Rothman    1958-06-07      19:56:21        59.18
# 4                Giles    1965-11-29      08:35:24        51.70
#
#    Weight in Kgs. Date of Joining Quarter of Joining Half of Joining  \
# 0              78      2004-02-22                 Q1              H1
# 1              79      2009-02-01                 Q1              H1
# 2              72      2016-02-14                 Q1              H1
# 3              51      2004-02-22                 Q1              H1
# 4              58      1988-02-28                 Q1              H1
#
#    Year of Joining  Month of Joining Month Name of Joining Short Month  \
# 0           2004.0                 2              February         Feb
# 1           2009.0                 2              February         Feb
# 2           2016.0                 2              February         Feb
# 3           2004.0                 2              February         Feb
# 4           1988.0                 2              February         Feb
#
#    Day of Joining DOW of Joining Short DOW  Age in Company (Years)  Salary  \
# 0              22         Sunday       Sun                   13.44  149793
# 1               1         Sunday       Sun                    8.49  133073
# 2              14         Sunday       Sun                    1.45   50982
# 3              22         Sunday       Sun                   13.44  171682
# 4              28         Sunday       Sun                   29.43  108261
#
#    Tax Eligibility  Tax Percentage  Last % Hike          SSN    Phone No.   \
# 0             True             NaN         0.25  403-73-7467  270-644-7854
# 1             True             NaN         0.01  626-85-9091  225-578-5774
# 2            False             NaN         0.24  654-38-3428  215-589-4268
# 3             True             NaN         0.16  158-23-7131  228-894-7251
# 4             True             NaN         0.02  083-02-2333  216-487-7347
#
#   Place Name    County       City State      Zip     Region      User Name  \
# 0  Pendleton     Henry  Pendleton    KY  40055.0      South        aqappel
# 1    Leander   Leander    Leander    LA  71445.0      South       aearvizu
# 2  Centralia  Columbia  Centralia    PA  17927.0  Northeast  bjbaskerville
# 3   Tribbett  Tribbett   Tribbett    MS  38779.0      South       enbaucom
# 4   Columbus  Franklin   Columbus    OH  43271.0    Midwest       nkbinder
#
#        Password  Unnamed: 40  Unnamed: 41  Unnamed: 42 count numerical value  \
# 0   v]v*;4FwqL>          NaN          NaN          NaN     count every value
# 1     7dUsJd!L#          NaN          NaN          NaN          count blanks
# 2    6WvugA]g5N          NaN          NaN          NaN               countif
# 3     8XkHcpm--          NaN          NaN          NaN                   NaN
# 4  nm-a7n_}^w4/          NaN          NaN          NaN                   NaN
#
#    Unnamed: 44    9993
# 0          NaN  9993.0
# 1          NaN     7.0
# 2          NaN   656.0
# 3          NaN     NaN
# 4          NaN     NaN

# %%
fd.columns
# Out:
# Index([                'Emp ID',             'MY PATTERN',
#                   'Name Prefix',             'First Name',
#                'Middle Initial',              'Last Name',
#                        'Gender',                 'E Mail',
#                 'Father's Name',          'Mother's Name',
#          'Mother's Maiden Name',          'Date of Birth',
#                 'Time of Birth',            'Age in Yrs.',
#                'Weight in Kgs.',        'Date of Joining',
#            'Quarter of Joining',        'Half of Joining',
#               'Year of Joining',       'Month of Joining',
#         'Month Name of Joining',            'Short Month',
#                'Day of Joining',         'DOW of Joining',
#                     'Short DOW', 'Age in Company (Years)',
#                        'Salary',        'Tax Eligibility',
#                'Tax Percentage',            'Last % Hike',
#                           'SSN',             'Phone No. ',
#                    'Place Name',                 'County',
#                          'City',                  'State',
#                           'Zip',                 'Region',
#                     'User Name',               'Password',
#                   'Unnamed: 40',            'Unnamed: 41',
#                   'Unnamed: 42',  'count numerical value',
#                   'Unnamed: 44',                     9993],
#       dtype='object')

# %%
reordered_cols =[[                'Emp ID',             'MY PATTERN',
                  'Name Prefix',             'First Name',
               'Middle Initial',              'Last Name',
                       'Gender',                 'E Mail',
                'Father's Name',          'Mother's Name',
         'Mother's Maiden Name',          'Date of Birth',
                'Time of Birth',            'Age in Yrs.',
               'Weight in Kgs.',        'Date of Joining',
           'Quarter of Joining',        'Half of Joining',
              'Year of Joining',       'Month of Joining',
        'Month Name of Joining',            'Short Month',
               'Day of Joining',         'DOW of Joining',
                    'Short DOW', 'Age in Company (Years)',
                       'Salary',        'Tax Eligibility',
               'Tax Percentage',            'Last % Hike',
                          'SSN',             'Phone No. ',
                   'Place Name',                 'County',
                         'City',                  'State',
                          'Zip',                 'Region',
                    'User Name',               'Password',
                  'Unnamed: 40',            'Unnamed: 41',
                  'Unnamed: 42',  'count numerical value',
                  'Unnamed: 44',                     9993]]
