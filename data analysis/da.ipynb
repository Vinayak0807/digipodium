# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
pd.read_excel('100000 records of sheet.xlsx',sheet_name=0,skiprows=None,skipfooter=0)
# Out:
#       Emp ID MY PATTERN Name Prefix First Name Middle Initial    Last Name  \
# 0     857665        NaN         Dr.     Antone              Q        Appel
# 1     223381        NaN         Mr.     Arthur              E       Arvizu
# 2     670592        NaN         Mr.      Brian              J  Baskerville
# 3     467879        NaN        Hon.       Elma              N       Baucom
# 4     184988        NaN        Drs.     Noella              K       Binder
# ...      ...        ...         ...        ...            ...          ...
# 9995  137698        NaN        Mrs.   Waltraud              L        Vigil
# 9996  356126        NaN         Dr.       Tony              T      Waltman
# 9997  850342        NaN         Mr.      Kirby              F      Wilhelm
# 9998  994968        NaN         Ms.      Darla              G      Windsor
# 9999  738024        NaN        Drs.      Staci              G         Word
#
#      Gender                        E Mail        Father's Name  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
fd = pd.read_excel('100000 records of sheet.xlsx',sheet_name=0,skiprows=None,skipfooter=0)

# %%
fd.head()
# Out:
#    Emp ID MY PATTERN Name Prefix First Name Middle Initial    Last Name  \
# 0  857665        NaN         Dr.     Antone              Q        Appel
# 1  223381        NaN         Mr.     Arthur              E       Arvizu
# 2  670592        NaN         Mr.      Brian              J  Baskerville
# 3  467879        NaN        Hon.       Elma              N       Baucom
# 4  184988        NaN        Drs.     Noella              K       Binder
#
#   Gender                      E Mail        Father's Name    Mother's Name  \
# 0      M      antone.appel@gmail.com          Micah Appel     Odette Appel
# 1      M  arthur.arvizu@ntlworld.com        Travis Arvizu    Reanna Arvizu
# 2      M   brian.baskerville@aol.com  Clayton Baskerville  Kum Baskerville
# 3      F  elma.baucom@rediffmail.com     Margarito Baucom     Elmer Baucom
# 4      F       noella.binder@ibm.com        Santos Binder   Sharice Binder
#
#   Mother's Maiden Name Date of Birth Time of Birth  Age in Yrs.  \
# ...

# %%
fd.columns
# Out:
# Index([                'Emp ID',             'MY PATTERN',
#                   'Name Prefix',             'First Name',
#                'Middle Initial',              'Last Name',
#                        'Gender',                 'E Mail',
#                 'Father's Name',          'Mother's Name',
#          'Mother's Maiden Name',          'Date of Birth',
#                 'Time of Birth',            'Age in Yrs.',
#                'Weight in Kgs.',        'Date of Joining',
#            'Quarter of Joining',        'Half of Joining',
#               'Year of Joining',       'Month of Joining',
#         'Month Name of Joining',            'Short Month',
#                'Day of Joining',         'DOW of Joining',
#                     'Short DOW', 'Age in Company (Years)',
#                        'Salary',        'Tax Eligibility',
#                'Tax Percentage',            'Last % Hike',
#                           'SSN',             'Phone No. ',
# ...

# %%
cols_to_drop=['MY PATTERN','Unnamed: 40',	'Unnamed: 41'	,'Unnamed: 42'	,'count numerical value'	,'Unnamed: 44']
fd.drop(columns=cols_to_drop , inplace=True)

# %%
fd
# Out:
#       Emp ID Name Prefix First Name Middle Initial    Last Name Gender  \
# 0     857665         Dr.     Antone              Q        Appel      M
# 1     223381         Mr.     Arthur              E       Arvizu      M
# 2     670592         Mr.      Brian              J  Baskerville      M
# 3     467879        Hon.       Elma              N       Baucom      F
# 4     184988        Drs.     Noella              K       Binder      F
# ...      ...         ...        ...            ...          ...    ...
# 9995  137698        Mrs.   Waltraud              L        Vigil      F
# 9996  356126         Dr.       Tony              T      Waltman      M
# 9997  850342         Mr.      Kirby              F      Wilhelm      M
# 9998  994968         Ms.      Darla              G      Windsor      F
# 9999  738024        Drs.      Staci              G         Word      F
#
#                             E Mail        Father's Name    Mother's Name  \
# ...

# %%
plt.figure(figsize=(30,3), dpi=300)
plt.bar('Year of Joining', 'Age in Company (Years)', data=fd)
plt.xticks(rotation=90)
plt.show()

# %%
fd.columns
# Out:
# Index([                'Emp ID',            'Name Prefix',
#                    'First Name',         'Middle Initial',
#                     'Last Name',                 'Gender',
#                        'E Mail',          'Father's Name',
#                 'Mother's Name',   'Mother's Maiden Name',
#                 'Date of Birth',          'Time of Birth',
#                   'Age in Yrs.',         'Weight in Kgs.',
#               'Date of Joining',     'Quarter of Joining',
#               'Half of Joining',        'Year of Joining',
#              'Month of Joining',  'Month Name of Joining',
#                   'Short Month',         'Day of Joining',
#                'DOW of Joining',              'Short DOW',
#        'Age in Company (Years)',                 'Salary',
#               'Tax Eligibility',         'Tax Percentage',
#                   'Last % Hike',                    'SSN',
#                    'Phone No. ',             'Place Name',
# ...

# %%
cols_to_drop =[  "Mother's Maiden Name",'Middle Initial']
fd.drop(cols_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 cols_to_drop =[  "Mother's Maiden Name",'Middle Initial']
# ----> 2 fd.drop(cols_to_drop)
#
# File c:\Users\Vinayak\miniconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
a ={'a':[1,2,3,4,5,6],'b':[5,4,7,8,9,6]}
