# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
#testing the water
pd.read_excel('Canada.xlsx',sheet_name=1,skiprows=20,skipfooter=2)
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_excel('Canada.xlsx',sheet_name=1,skiprows=20,skipfooter=2)

# %% [markdown]
# -what to learn
# -selection of data
#  -row selection
#    > slicing
#    >head
#    >tail
#    >iloc
#    >loc
# -columns selection
#   >object style
#   >dictionary style

# %%
df.iloc[[-1,20,15,7]]
# Out:
#            Type    Coverage     OdName  AREA                         AreaName  \
# 194  Immigrants  Foreigners   Zimbabwe   903                           Africa
# 20   Immigrants  Foreigners     Bhutan   935                             Asia
# 15   Immigrants  Foreigners   Barbados   904  Latin America and the Caribbean
# 7    Immigrants  Foreigners  Argentina   904  Latin America and the Caribbean
#
#       REG         RegName  DEV             DevName  1980  1981  1982  1983  \
# 194   910  Eastern Africa  902  Developing regions    72   114   102    44
# 20   5501   Southern Asia  902  Developing regions     0     0     0     0
# 15    915       Caribbean  902  Developing regions   372   376   299   244
# 7     931   South America  902  Developing regions   368   426   626   241
#
#      1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  \
# 194    32    29    43    68    99   187   129    94    61    72    78    58
# ...

# %%
df.iloc[:, :5]
# Out:
#            Type    Coverage          OdName  AREA AreaName
# 0    Immigrants  Foreigners     Afghanistan   935     Asia
# 1    Immigrants  Foreigners         Albania   908   Europe
# 2    Immigrants  Foreigners         Algeria   903   Africa
# 3    Immigrants  Foreigners  American Samoa   909  Oceania
# 4    Immigrants  Foreigners         Andorra   908   Europe
# ..          ...         ...             ...   ...      ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia
# 191  Immigrants  Foreigners  Western Sahara   903   Africa
# 192  Immigrants  Foreigners           Yemen   935     Asia
# 193  Immigrants  Foreigners          Zambia   903   Africa
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa
#
# [195 rows x 5 columns]

# %%
#we are taking all rows and 0,1,4,5 columns
df.iloc[:, [0,1,4,5]]
# Out:
#            Type    Coverage AreaName   REG
# 0    Immigrants  Foreigners     Asia  5501
# 1    Immigrants  Foreigners   Europe   925
# 2    Immigrants  Foreigners   Africa   912
# 3    Immigrants  Foreigners  Oceania   957
# 4    Immigrants  Foreigners   Europe   925
# ..          ...         ...      ...   ...
# 190  Immigrants  Foreigners     Asia   920
# 191  Immigrants  Foreigners   Africa   912
# 192  Immigrants  Foreigners     Asia   922
# 193  Immigrants  Foreigners   Africa   910
# 194  Immigrants  Foreigners   Africa   910
#
# [195 rows x 4 columns]

# %%
print(print(df.columns))
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
# None

# %%
print(df.columns.tolist())
# Out:
# ['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName', 'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
df['AreaName']
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
#multiple columns
col_list =[1980,2000,2013]
df[col_list]
# Out:
#      1980  2000  2013
# 0      16  3326  2004
# 1       1  1816   603
# 2      80  2867  4331
# 3       0     0     0
# 4       0     0     1
# ..    ...   ...   ...
# 190  1191  1803  2112
# 191     0     0     0
# 192     1   122   217
# 193    11    39    59
# 194    72    98   407
#
# [195 rows x 3 columns]

# %%
df[[1980,2000,2001,2005]][5:10]
# Out:
#    1980  2000  2001  2005
# 5     1    70   169   295
# 6     0    13    25    24
# 7   368   427   635  1153
# 8     0   124    87   224
# 9   702   599   799   909

# %% [markdown]
# maths and stats

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  1981  1982  1983  1984  \
# 0    Southern Asia  902  Developing regions    16    39    39    47    71
# 1  Southern Europe  901   Developed regions     1     0     0     0     0
# 2  Northern Africa  902  Developing regions    80    67    71    69    63
# 3        Polynesia  902  Developing regions     0     1     0     0     0
# 4  Southern Europe  901   Developed regions     0     0     0     0     0
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
df.describe(exclude=np.number)  # non-numeric columns summary
# Out:
#               Type    Coverage       OdName AreaName       RegName  \
# count          195         195          195      195           195
# unique           1           2          195        6            22
# top     Immigrants  Foreigners  Afghanistan   Africa  Western Asia
# freq           195         194            1       54            18
#
#                    DevName
# count                  195
# unique                   2
# top     Developing regions
# freq                   147

# %%
df[2010].sum()
# Out:
# 276956

# %%
df[[1980,1981,1982,1983,1984]].sum(axis=1)
# Out:
# 0        212
# 1          1
# 2        350
# 3          1
# 4          0
#        ...
# 190    16169
# 191        0
# 192       10
# 193       62
# 194      364
# Length: 195, dtype: int64

# %%
years = list(range(1980,2014))
print(years)
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
df['total']=df[years].sum(axis=1)
df.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  1981  1982  1983  1984  \
# 0    Southern Asia  902  Developing regions    16    39    39    47    71
# 1  Southern Europe  901   Developed regions     1     0     0     0     0
# 2  Northern Africa  902  Developing regions    80    67    71    69    63
# 3        Polynesia  902  Developing regions     0     1     0     0     0
# 4  Southern Europe  901   Developed regions     0     0     0     0     0
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# ...

# %%
plt.figure(figsize=(30,3), dpi=300)
plt.bar('OdName', 'Total', data=df)
plt.xticks(rotation=90)
plt.show()
