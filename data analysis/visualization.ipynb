# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[0,1,2,3,4,5,6,]
y=[23,22,30,35,45,45,55]
plt.plot(x, y)

# %%
plt.plot(x,y,color = 'red',marker ='o',linestyle='--')

# %%
plt.plot(x,y,color = 'red',marker ='o',linestyle='--')

# %%
plt.plot(x,y,color = 'red',marker ='o',linestyle='--')
# add text to each point in graph
plt.plot(x,y, color='red', marker='o', linestyle='--')
for i in range(len(x)):
    plt.text(x[i]-.2, y[i]+2, str(y[i]))
plt.text(0, 50, "A random graph", fontsize=12, color='blue')
# Out:
# Text(0, 50, 'A random graph')

# %%
plt.plot(x,y)
plt.xlim(0,7)
plt.ylim(20,80)
# Out:
# (20.0, 80.0)

# %%
plt.plot(x,y,color = 'green',marker ='o',linestyle='--',label='line 1',facecolor)
plt.title('a random graph')
plt.xlabel('x values')
plt.ylabel('y label')
plt.legend()
plt.xticks(np.arange(0,9),rotation=45)
plt.show
# Out:
#   Cell In[28], line 1
#     plt.plot(x,y,color = 'green',marker ='o',linestyle='--',label='line 1',facecolor)
#                                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")
tips.head()
# Out:
# c:\Users\Vinayak\miniconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")
# Out:
# c:\Users\Vinayak\miniconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")
# Out:
# c:\Users\Vinayak\miniconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df=sns.load_dataset('titanic')

# %%
sns.jointplot(x='fare',y='age',data=df, kind='kde')

# %%
penguin= sns.load_dataset('penguins')
penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.pairplot(penguin, kind='kde',hue='species')
# Out:
# c:\Users\Vinayak\miniconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import plotly.express as px

# %%
import plotly.express as px
df = px.data.tips()
fig = px.parallel_categories(df, color="size", color_continuous_scale=px.colors.sequential.Inferno)
fig.show()
